// %%
import java.nio.channels.ReadPendingException

Basics
WAP to find page title, landed URL, page source i.e DOM
WAP to forgot password and relogin.
WAP to maximize,fullscreen, land URL without get, backward, forward
WAP to navigate 1. sibling to down sibling 2 sibling to up sibling 3. sibling to parent 4. sibling to ancestor
WAP to :-
 select and verify selected value from static dropdown with select class
 select and verify multiple selected value from static dropdown with not select class
 select value from dynamic dropdown (using parent child relationship)
 select value from autosuggestive dropdown
 select any checkbox,tool tip, verify if its checked,count total no of checkbox in a page
 select current date from calendar // for assertion with current system date use date and SimpleDateFormat class
 Select any desired or future date from calender-Pending
 Verify webelement enabled or not without using isEnabled method(discrepancy),use getDOMAttribut("attributename")

WAP for windows alert like
1. acknowledge [positive (ok,Yes) or negative(cancel, no)],2.Fetch & Verify Alert text
WAP for Authentication alert (like enter username, password in alert) -Pending

WAP to Add to cart for specific elements
WAP for fluent wait
WAP for
1. mousehover element 2. type in uppercase 3. select the text on screen 4. right click
WAP to type username fectched from another window
WAP to print first text present in child window after that text present in parent window

WAP for drag and drop, selectable, reorder, resizable, Assignment
WAP (limitingwebdriverscope) VVI
1. total no. of links in page
2. total no. of links in footersection of page
3. total no. of links in 1st column out of 5 columns in footersection of page
4. Click on each 1st column link and check if pages (windows) are open or not
5. Assignment(imp)
a. Select any checkBox
b. Grab the text of selected checkbox
c. select option in dropdown which is text/label of selected checkbox
d. Enter the label text in popup textbox
e. verify the pop message contains checkbox label or not

WAP to select a given date and verify if it's selected VVI - Done

WAP scroll entire webpage
WAP scroll inside table element in webpage
WAP to calculate sum of amount in table, both table try Done

WAP to handle SSL certification (go to advance page or private message,comes before webpage- pending, write for firefox and edge, safari as well - done
WAP to add extension in browser - done
WAP to set proxy in browser - done
WAP to block automatic pop up windows - done
WAP to set downloaded directory/attachment path - done
WAP to maximize screen - done
WAP to delete all cookies , specific cooky, add cooky
WAP to app  logout after deleting session cooky
(steps= delete session cooky,click on anylink->application should automatically logout i.e login page should display-> verify login URL) - done
WAP to take screenshot (always use user profile directory for storing screenshot file instead of direct inside C due to access issue))


 VVI Programs-
WAP  for verifying broken links(not working URL) in webpage - PENDING VVI - done
WAP for verify sort table - VVI done
WAP to get 2nd column corresponding data w.r.t 1st column data, like price of specific vegatable in table in any page - VVI done
WAP for search filter, text in search bar matches with result in table - VVI done

Selenium4
WAP to grab Name title using above above relative locator- done
WAP to enter some date input in DOB using below relative locator - cannot do due to flex element limitation, do submit - done
WAP to select checkbox of some specified title, use toLeftOf relative locator - done
WAP to find of dynamiclabel of radio button, use toRightOf relative locator - done
WAP to enter text in Name label of 1st URL from grabbed 1st course from another 2nd  URL- VVI - done
WAP to take name webelement screenshot - done
WAP to take webelement dimension i.e height and width of textbox let say name textbox in above example- done
